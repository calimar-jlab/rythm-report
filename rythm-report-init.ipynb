# %%
import os
from dotenv import load_dotenv

load_dotenv()

SPOTIPY_CLIENT_ID = os.getenv("SPOTIPY_CLIENT_ID")
SPOTIPY_CLIENT_SECRET = os.getenv("SPOTIPY_CLIENT_SECRET")
USER = os.getenv("USER")

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

auth_manager = SpotifyClientCredentials(
    client_id = SPOTIPY_CLIENT_ID,
    client_secret = SPOTIPY_CLIENT_SECRET
)
sp = spotipy.Spotify(auth_manager=auth_manager)

playlists = sp.user_playlists(
    user = USER,
    limit = 100
)

# %%
import pandas as pd
import statistics as stat

# %%
# define playlists to pull
## more work needed for automation
year_starting = 2024
years = 2
months = 12

pl_names = [None] * years * months

# auto generate list of playlist names based on range provided (format mm.yyyy)
for years_iter in range(years):
    for months_iter in range(months):
        months_str = str((months_iter + 1)).zfill(2) # format single digit values as 01, 02 etc.
        years_str = year_starting + years_iter
        if years_iter == 0:
            pl_names[months_iter]= f"{months_str}.{years_str}"
        else:
            pl_names[(months_iter + 12)] = f"{months_str}.{years_str}"

# get item info from init data load
pl_info = pd.DataFrame(playlists["items"])

# filter playlists for date range defined previously
pl_filter = pl_info["name"].isin(pl_names)

# create new dataframe filtered for scope of analysis (2024 - 2025 inc.)
pl_scope = pl_info[pl_filter]
pl_scope = pl_scope[["images", "name", "tracks", "id"]]

pl_scope = pl_scope.reset_index(drop = True)

### get playlist covers
num_pl = len(pl_scope)
pl_covers = [None] * num_pl

for i in range(num_pl):
    pl_scope["images"].iloc[i] = sp.playlist_cover_image(pl_scope["id"].iloc[i])

# %%
### get playlist track information
# define 'flattened' list for collecting normalised json responses
pl_tracks = [None] * num_pl
flattened = [None] * num_pl
for i in range(num_pl):
    pl_tracks[i] = sp.playlist_items(
        # take playlist id from master pl df
        playlist_id = pl_scope["id"].iloc[i],
        # specify fields wanted. Take track details for this list
        fields = "items.track.id, items.track.name, items.track.duration_ms, items.track.popularity"
    )["items"]
    # returns json lists, normalise:
    flattened[i] = pd.json_normalize(pl_tracks[i], sep="_")
    # clean headers
    flattened[i].columns = flattened[i].columns.str.replace("track_", "")
    flattened[i]["playlist_id"] = pl_scope["id"].iloc[i]

# %%
flattened[0]
# Out:
#     duration_ms                                     name  popularity  \
# 0        200045          POP POP POP (feat. Danny Brown)          38
# 1        180724                             IS THIS LOVE          50
# 2        229373                           Everybody Wins          32
# 3        180807                             I See Myself          59
# 4        145506                            GIVE IT TO ME          49
# 5        205866                            Legend Has It          59
# 6        345796                          movies for guys          49
# 7        279693         Moonage Daydream - 2012 Remaster          69
# 8        168146                                おちゃんせんすぅす          36
# 9        212000           Stop Pretending you Like Salad          52
# 10        94670                                     And1          41
# 11       243232                                Deus Deus          59
# 12       353260                         Playing Classics          48
# 13       182123  BOYS WITH THE CHARACTERISTICS OF WOLVES          46
# 14       228783                     Heaven Is No Feeling          49
# 15       151011                              I Got Views          55
# 16       598360                          Look Down On Us          50
# 17       168863                             Toria's Song          30
# 18       211875               bite my tongue - unplugged          47
# 19       176712                                  EMBASSY           0
# 20       163253                                    Moxie          11
# 21       288450                                  Waiting          41
#
#                         id             playlist_id
# 0   5gGHRgEQ2wfgjKRyPaOG2P  5NDD0eLJwABWYVzyB0fIF6
# 1   4SrhXzAN9P1LJlkvs91PKe  5NDD0eLJwABWYVzyB0fIF6
# 2   6YZTTcD1W9vGNGw8Yzicgt  5NDD0eLJwABWYVzyB0fIF6
# 3   4gFFHAj5iwUEHwPpjZTdi5  5NDD0eLJwABWYVzyB0fIF6
# 4   7xvWCrjw6cO2oyGX8J1A0V  5NDD0eLJwABWYVzyB0fIF6
# 5   7satW8tFLasyZbftvrWFBP  5NDD0eLJwABWYVzyB0fIF6
# 6   1urgZoAjz91vFqPEokA1OR  5NDD0eLJwABWYVzyB0fIF6
# 7   6mib3N4E8PZHAGQ3xy7bho  5NDD0eLJwABWYVzyB0fIF6
# 8   7pVJtMyNMXlYBh4MevJ692  5NDD0eLJwABWYVzyB0fIF6
# 9   6fTH4b7b5Mvp9xxOSoDiZl  5NDD0eLJwABWYVzyB0fIF6
# 10  2cH4QYxI5DmFPJySqiXaxv  5NDD0eLJwABWYVzyB0fIF6
# 11  0Qrm0QyIXutGY2nPJxS3tD  5NDD0eLJwABWYVzyB0fIF6
# 12  3Bl4FyRBIaOSvvYI6zHbpq  5NDD0eLJwABWYVzyB0fIF6
# 13  7ApBgRUeHjs5VpHRYdWya9  5NDD0eLJwABWYVzyB0fIF6
# 14  6QyDopDgclGYNXf3UeuDZv  5NDD0eLJwABWYVzyB0fIF6
# 15  3TBw3obkWdPfMv1qdlXYi0  5NDD0eLJwABWYVzyB0fIF6
# 16  3KQFlED2WlEBOFRK61eI05  5NDD0eLJwABWYVzyB0fIF6
# 17  1Zz21MrR92xpFsI1GsGsud  5NDD0eLJwABWYVzyB0fIF6
# 18  4MFFiam7A0M0rjzN5S7Rug  5NDD0eLJwABWYVzyB0fIF6
# 19  06AgC3PomjqWzA206dOrwU  5NDD0eLJwABWYVzyB0fIF6
# 20  3yV343XLWPtzNH1qiymbxq  5NDD0eLJwABWYVzyB0fIF6
# 21  6fgGUaT6f1hmfLSSsAjuKM  5NDD0eLJwABWYVzyB0fIF6
